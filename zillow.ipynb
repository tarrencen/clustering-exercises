# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from env import get_db_url

# %%
url = get_db_url('zillow')

pd.read_sql('SHOW TABLES', url)
# Out:
#           Tables_in_zillow
# 0      airconditioningtype
# 1   architecturalstyletype
# 2        buildingclasstype
# 3      heatingorsystemtype
# 4         predictions_2016
# 5         predictions_2017
# 6          properties_2016
# 7          properties_2017
# 8      propertylandusetype
# 9                storytype
# 10    typeconstructiontype
# 11       unique_properties

# %%
pd.read_sql('DESCRIBE properties_2017', url)
# Out:
#                            Field        Type Null  Key Default Extra
# 0                             id      bigint  YES  MUL    None
# 1                       parcelid      bigint  YES  MUL    None
# 2          airconditioningtypeid      double  YES         None
# 3       architecturalstyletypeid      double  YES         None
# 4                   basementsqft      double  YES         None
# 5                    bathroomcnt      double  YES         None
# 6                     bedroomcnt      double  YES         None
# 7            buildingclasstypeid      double  YES         None
# 8          buildingqualitytypeid      double  YES         None
# 9              calculatedbathnbr      double  YES         None
# 10                    decktypeid      double  YES         None
# 11      finishedfloor1squarefeet      double  YES         None
# 12  calculatedfinishedsquarefeet      double  YES         None
# 13          finishedsquarefeet12      double  YES         None
# 14          finishedsquarefeet13      double  YES         None
# 15          finishedsquarefeet15      double  YES         None
# 16          finishedsquarefeet50      double  YES         None
# 17           finishedsquarefeet6      double  YES         None
# 18                          fips      double  YES         None
# 19                  fireplacecnt      double  YES         None
# 20                   fullbathcnt      double  YES         None
# 21                  garagecarcnt      double  YES         None
# 22               garagetotalsqft      double  YES         None
# 23                hashottuborspa  tinyint(1)  YES         None
# 24         heatingorsystemtypeid      double  YES         None
# 25                      latitude      double  YES         None
# 26                     longitude      double  YES         None
# 27             lotsizesquarefeet      double  YES         None
# 28                       poolcnt      double  YES         None
# 29                   poolsizesum      double  YES         None
# 30                  pooltypeid10      double  YES         None
# 31                   pooltypeid2      double  YES         None
# 32                   pooltypeid7      double  YES         None
# 33     propertycountylandusecode        text  YES         None
# 34         propertylandusetypeid      double  YES         None
# 35            propertyzoningdesc        text  YES         None
# 36        rawcensustractandblock      double  YES         None
# 37                  regionidcity      double  YES         None
# 38                regionidcounty      double  YES         None
# 39          regionidneighborhood      double  YES         None
# 40                   regionidzip      double  YES         None
# 41                       roomcnt      double  YES         None
# 42                   storytypeid      double  YES         None
# 43           threequarterbathnbr      double  YES         None
# 44        typeconstructiontypeid      double  YES         None
# 45                       unitcnt      double  YES         None
# 46            yardbuildingsqft17      double  YES         None
# 47            yardbuildingsqft26      double  YES         None
# 48                     yearbuilt      double  YES         None
# 49               numberofstories      double  YES         None
# 50                 fireplaceflag  tinyint(1)  YES         None
# 51    structuretaxvaluedollarcnt      double  YES         None
# 52             taxvaluedollarcnt      double  YES         None
# 53                assessmentyear      double  YES         None
# 54         landtaxvaluedollarcnt      double  YES         None
# 55                     taxamount      double  YES         None
# 56            taxdelinquencyflag        text  YES         None
# 57            taxdelinquencyyear      double  YES         None
# 58           censustractandblock      double  YES         None

# %%
pd.read_sql('DESCRIBE propertylandusetype', url)
# Out:
#                    Field    Type Null  Key Default Extra
# 0  propertylandusetypeid  bigint   NO  PRI    None
# 1    propertylandusedesc    text  YES         None

# %%
pd.read_excel('zillow_data_dictionary.xlsx')
# Out:
#                            Feature  \
# 0          'airconditioningtypeid'
# 1       'architecturalstyletypeid'
# 2                   'basementsqft'
# 3                    'bathroomcnt'
# 4                     'bedroomcnt'
# 5          'buildingqualitytypeid'
# 6            'buildingclasstypeid'
# 7              'calculatedbathnbr'
# 8                     'decktypeid'
# 9            'threequarterbathnbr'
# 10      'finishedfloor1squarefeet'
# 11  'calculatedfinishedsquarefeet'
# 12           'finishedsquarefeet6'
# 13          'finishedsquarefeet12'
# 14          'finishedsquarefeet13'
# 15          'finishedsquarefeet15'
# 16          'finishedsquarefeet50'
# 17                          'fips'
# 18                  'fireplacecnt'
# 19                 'fireplaceflag'
# 20                   'fullbathcnt'
# 21                  'garagecarcnt'
# 22               'garagetotalsqft'
# 23                'hashottuborspa'
# 24         'heatingorsystemtypeid'
# 25                      'latitude'
# 26                     'longitude'
# 27             'lotsizesquarefeet'
# 28               'numberofstories'
# 29                      'parcelid'
# 30                       'poolcnt'
# 31                   'poolsizesum'
# 32                  'pooltypeid10'
# 33                   'pooltypeid2'
# 34                   'pooltypeid7'
# 35     'propertycountylandusecode'
# 36         'propertylandusetypeid'
# 37            'propertyzoningdesc'
# 38        'rawcensustractandblock'
# 39           'censustractandblock'
# 40                'regionidcounty'
# 41                  'regionidcity'
# 42                   'regionidzip'
# 43          'regionidneighborhood'
# 44                       'roomcnt'
# 45                   'storytypeid'
# 46        'typeconstructiontypeid'
# 47                       'unitcnt'
# 48            'yardbuildingsqft17'
# 49            'yardbuildingsqft26'
# 50                     'yearbuilt'
# 51             'taxvaluedollarcnt'
# 52    'structuretaxvaluedollarcnt'
# 53         'landtaxvaluedollarcnt'
# 54                     'taxamount'
# 55                'assessmentyear'
# 56            'taxdelinquencyflag'
# 57            'taxdelinquencyyear'
#
#                                           Description
# 0    Type of cooling system present in the home (i...
# 1    Architectural style of the home (i.e. ranch, ...
# 2    Finished living area below or partially below...
# 3    Number of bathrooms in home including fractio...
# 4                         Number of bedrooms in home
# 5    Overall assessment of condition of the buildi...
# 6   The building framing type (steel frame, wood f...
# 7    Number of bathrooms in home including fractio...
# 8             Type of deck (if any) present on parcel
# 9    Number of 3/4 bathrooms in house (shower + si...
# 10   Size of the finished living area on the first...
# 11   Calculated total finished living area of the ...
# 12                  Base unfinished and finished area
# 13                               Finished living area
# 14                             Perimeter  living area
# 15                                         Total area
# 16   Size of the finished living area on the first...
# 17   Federal Information Processing Standard code ...
# 18            Number of fireplaces in a home (if any)
# 19               Is a fireplace present in this home
# 20   Number of full bathrooms (sink, shower + bath...
# 21   Total number of garages on the lot including ...
# 22   Total number of square feet of all garages on...
# 23                Does the home have a hot tub or spa
# 24                        Type of home heating system
# 25   Latitude of the middle of the parcel multipli...
# 26   Longitude of the middle of the parcel multipl...
# 27                     Area of the lot in square feet
# 28           Number of stories or levels the home has
# 29              Unique identifier for parcels (lots)
# 30                Number of pools on the lot (if any)
# 31      Total square footage of all pools on property
# 32                                     Spa or Hot Tub
# 33                              Pool with Spa/Hot Tub
# 34                               Pool without hot tub
# 35   County land use code i.e. it's zoning at the ...
# 36         Type of land use the property is zoned for
# 37   Description of the allowed land uses (zoning)...
# 38   Census tract and block ID combined - also con...
# 39   Census tract and block ID combined - also con...
# 40            County in which the property is located
# 41     City in which the property is located (if any)
# 42          Zip code in which the property is located
# 43      Neighborhood in which the property is located
# 44   Total number of rooms in the principal residence
# 45   Type of floors in a multi-story house (i.e. b...
# 46   What type of construction material was used t...
# 47   Number of units the structure is built into (...
# 48                                     Patio in  yard
# 49                      Storage shed/building in yard
# 50        The Year the principal residence was built
# 51         The total tax assessed value of the parcel
# 52  The assessed value of the built structure on t...
# 53  The assessed value of the land area of the parcel
# 54  The total property tax assessed for that asses...
# 55           The year of the property tax assessment
# 56  Property taxes for this parcel are past due as...
# 57  Year for which the unpaid propert taxes were due

# %% [markdown]
# ### Acquire data from mySQL using the python module to connect and query. You will want to end with a single dataframe. Make sure to include: the logerror, all fields related to the properties that are available. You will end up using all the tables in the database.
#
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.
#
# - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction.
#
# - Only include properties that include a latitude and longitude value
